# %% [markdown]
# # Placebo in space
#
# If a donor city shows a gap as large as the treated city, the fare headline is noise.
# This notebook just re-runs the folder script and points at the board.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()))
import main as m
m.main()
print('open ../site/index.html and switch the donor dropdown')
