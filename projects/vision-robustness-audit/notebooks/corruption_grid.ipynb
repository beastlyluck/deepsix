# %% [markdown]
# # Corruption grid
#
# Accuracy vs severity. Fog and motion blur are the cells a dock camera should lose on.
# Click the board after the run; do not quote a single clean accuracy.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()))
import main as m
m.main()
print('open ../site/index.html and click a red cell')
