# %% [markdown]
# # Drift gate
#
# Campus kWh with heat arriving early in the last two weeks. The gate should fire on temperature PSI, not on a pretty MAPE.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()))
import numpy as np
import main as m

rng = np.random.default_rng(5)
df = m.make_campus(rng)
print(df.groupby(df['day'] >= m.DAYS - m.EVAL_DAYS)['temp'].mean())

# %%
m.main()
print('open ../site/index.html — move the heat slider')
